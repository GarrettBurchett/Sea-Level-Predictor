# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('epa-sea-level.csv')
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  ...  Upper Error Bound  NOAA Adjusted Sea Level
# 0  1880                  0.000000  ...           0.952756                      NaN
# 1  1881                  0.220472  ...           1.173228                      NaN
# 2  1882                 -0.440945  ...           0.464567                      NaN
# 3  1883                 -0.232283  ...           0.665354                      NaN
# 4  1884                  0.590551  ...           1.464567                      NaN
#
# [5 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      134 non-null    int64
#  1   CSIRO Adjusted Sea Level  134 non-null    float64
#  2   Lower Error Bound         134 non-null    float64
#  3   Upper Error Bound         134 non-null    float64
#  4   NOAA Adjusted Sea Level   21 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 5.4 KB

# %%
fig, ax = plt.subplots(figsize=(12,9))
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'])
plt.title('Rise in Sea Level')
plt.xlabel('Year')
plt.ylabel('Sea Level (Inches)')
plt.show()

# %%
regres = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
x2 = list(range(1880, 2050))
y2 = [regres.intercept + regres.slope * year for year in x2]
fig, ax = plt.subplots(figsize=(12,9))
plt.plot(x2, y2, 'r', label='1st fitted line')
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'])
plt.title('Rise in Sea Level')
plt.xlabel('Year')
plt.ylabel('Sea Level (Inches)')
plt.show()

# %%
regres2 = linregress(df['Year'].iloc[120:], df['CSIRO Adjusted Sea Level'].iloc[120:])
new_x = list(range(2000, 2050))
new_y = [regres2.intercept + regres2.slope * year2 for year2 in new_x]
fig, ax = plt.subplots(figsize=(12,9))
plt.plot(new_x, new_y, 'g', label='2nd fitted line')
plt.plot(x2, y2, 'r', label='1st fitted line')
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'])
plt.title('Rise in Sea Level')
plt.xlabel('Year')
plt.ylabel('Sea Level (Inches)')
plt.show()
